# %%
import numpy as np # used for handling numbers
import pandas as pd # used for handling the dataset
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer # used for handling missing data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder # used for encoding categorical data
from sklearn.model_selection import train_test_split # used for splitting training and testing data
from sklearn.preprocessing import StandardScaler # used for feature scaling

# %%
df = pd.read_csv("data - data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
df.shape
# Out:
# (18207, 89)

# %%
#Let's remove the unnamed column... It will not affect the predictions in future
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# ...

# %%
df["Age"].unique()
# Out:
# array([31, 33, 26, 27, 32, 25, 29, 28, 24, 30, 19, 40, 22, 23, 34, 35, 36,
#        37, 21, 18, 20, 39, 41, 17, 38, 45, 42, 16, 44], dtype=int64)

# %%
df["Value"].value_counts()
# Out:
# €1.1M      431
# €375K      372
# €425K      354
# €325K      351
# €450K      343
#           ...
# €36M         1
# €43M         1
# €46M         1
# €59M         1
# €110.5M      1
# Name: Value, Length: 217, dtype: int64

# %%
# To chk whether there is a null value or not
df.isnull().sum()
# Out:
# ID                   0
# Name                 0
# Age                  0
# Photo                0
# Nationality          0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 88, dtype: int64

# %%
df["Loaned From"].isnull().sum()
# Out:
# 16943

# %%
# Since there are 16943 data are missing out of total 18207 data points... so remove it
df.drop("Loaned From",axis=1,inplace=True)

# %%
df
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# ...

# %%
df["Work Rate"].value_counts()
# Out:
# Medium/ Medium    9810
# High/ Medium      3173
# Medium/ High      1690
# High/ High        1015
# Medium/ Low        850
# High/ Low          699
# Low/ Medium        449
# Low/ High          439
# Low/ Low            34
# Name: Work Rate, dtype: int64

# %%
df["Body Type"].value_counts()
# Out:
# Normal                 10595
# Lean                    6417
# Stocky                  1140
# Messi                      1
# C. Ronaldo                 1
# Neymar                     1
# Courtois                   1
# PLAYER_BODY_TYPE_25        1
# Shaqiri                    1
# Akinfenwa                  1
# Name: Body Type, dtype: int64

# %%
df["Real Face"].value_counts()
# Out:
# No     16505
# Yes     1654
# Name: Real Face, dtype: int64

# %%
df["Position"].value_counts()
# Out:
# ST     2152
# GK     2025
# CB     1778
# CM     1394
# LB     1322
# RB     1291
# RM     1124
# LM     1095
# CAM     958
# CDM     948
# RCB     662
# LCB     648
# LCM     395
# RCM     391
# LW      381
# RW      370
# RDM     248
# LDM     243
# LS      207
# RS      203
# RWB      87
# LWB      78
# CF       74
# LAM      21
# RAM      21
# RF       16
# LF       15
# Name: Position, dtype: int64

# %%
cat_cols = ["Preferred Foot", "Work Rate", "Body Type", "Real Face", "Position"]

# %%
# Encoding the categorical columns to numerical values...
for cols in cat_cols:
    le = LabelEncoder()
    df[cols] = le.fit_transform(df[cols])

# %%
df
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# ...

# %%
df["Preferred Foot"].value_counts()
# Out:
# 1    13948
# 0     4211
# 2       48
# Name: Preferred Foot, dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 4      192985        K. De Bruyne   27
# 5      183277           E. Hazard   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5      https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# ...                                               ...         ...
# ...

# %% [markdown]
# ### The no. of rows is decreased by 3464 which doesn't affect our data much... as there are still 14743 rows

# %%
df.isnull().sum()
# Out:
# ID                0
# Name              0
# Age               0
# Photo             0
# Nationality       0
#                  ..
# GKHandling        0
# GKKicking         0
# GKPositioning     0
# GKReflexes        0
# Release Clause    0
# Length: 87, dtype: int64

# %%
df[["Value","Wage","Release Clause"]].head()
# Out:
#      Value   Wage Release Clause
# 0  €110.5M  €565K        €226.5M
# 1     €77M  €405K        €127.1M
# 2  €118.5M  €290K        €228.1M
# 4    €102M  €355K        €196.4M
# 5     €93M  €340K        €172.1M

# %%
# as we can see that value,wage & Release Clause columns are in string we have to convert them to float values
def strtofloat(euros):
    if euros[-1]=='M':
        return float(euros[1:-1])*1000000
    if euros[-1]=='K':
        return float(euros[1:-1])*1000
    else:
        return float(euros[1:-1])

df['Value']=df['Value'].apply(lambda x: strtofloat(x))

df['Wage']=df['Wage'].apply(lambda x: strtofloat(x))

df['Release Clause']=df['Release Clause'].apply(lambda x: strtofloat(x))

# %%
df[["Name","Value","Wage","Release Clause"]].head()
# Out:
#                 Name        Value      Wage  Release Clause
# 0           L. Messi  110500000.0  565000.0     226500000.0
# 1  Cristiano Ronaldo   77000000.0  405000.0     127100000.0
# 2          Neymar Jr  118500000.0  290000.0     228100000.0
# 4       K. De Bruyne  102000000.0  355000.0     196400000.0
# 5          E. Hazard   93000000.0  340000.0     172100000.0

# %% [markdown]
# ### Now since there are no null values in the dataset , we can perform the visualization of our data...

# %%
df
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 4      192985        K. De Bruyne   27
# 5      183277           E. Hazard   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5      https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# ...                                               ...         ...
# ...

# %%
df["Nationality"].value_counts()
# Out:
# England                 1320
# Germany                  993
# Spain                    866
# France                   757
# Argentina                741
#                         ...
# New Caledonia              1
# Fiji                       1
# São Tomé & Príncipe        1
# United Arab Emirates       1
# Botswana                   1
# Name: Nationality, Length: 160, dtype: int64

# %%
sns.distplot(df["Age"])
# Out:
# C:\Users\vedan\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## Visualizing age of the players

# %%
plt.figure(figsize=[10,7])
plt.hist(df["Age"])
plt.title("Distribution of age")
plt.grid()
plt.show()

# %% [markdown]
# ### Hence most people are from age 20 to 25

# %%
plt.figure(figsize=[10,7])
plt.hist(df["Overall"])
plt.title("Distribution of overall")
plt.grid()
plt.show()

# %%
plt.figure(figsize=[10,7])
plt.hist(df["Wage"])
plt.title("Distribution of Wage")
plt.grid()
plt.show()

# %% [markdown]
# ### Mostly the players have rating in range 60 to 75

# %%
df["Nationality"].value_counts().head(40).plot(kind="bar",figsize=[15,5])
plt.show()

# %% [markdown]
# ### Hence most of the players are from England

# %%
plt.hist(df["Value"])
# Out:
# (array([1.411e+04, 4.290e+02, 1.210e+02, 3.900e+01, 1.500e+01, 1.500e+01,
#         8.000e+00, 3.000e+00, 1.000e+00, 2.000e+00]),
#  array([1.00000e+04, 1.18590e+07, 2.37080e+07, 3.55570e+07, 4.74060e+07,
#         5.92550e+07, 7.11040e+07, 8.29530e+07, 9.48020e+07, 1.06651e+08,
#         1.18500e+08]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df["Wage"])
# Out:
# (array([1.4356e+04, 2.4700e+02, 8.6000e+01, 3.0000e+01, 7.0000e+00,
#         7.0000e+00, 6.0000e+00, 2.0000e+00, 1.0000e+00, 1.0000e+00]),
#  array([  1000.,  57400., 113800., 170200., 226600., 283000., 339400.,
#         395800., 452200., 508600., 565000.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Hence most of the players have wages in range of 0 to 50,000

# %%
plt.scatter(df["Preferred Foot"].head(10),df["Name"].head(10))
plt.show()

# %%
pd.crosstab(df["Name"],df["Preferred Foot"])
# Out:
# Preferred Foot  0  1
# Name
# A. Abang        0  1
# A. Abdellaoui   1  0
# A. Abdi         0  1
# A. Abdu Jaber   0  1
# A. Ablet        1  0
# ...            .. ..
# Óliver Torres   0  1
# Óscar Gil       0  1
# Óscar Pinchi    0  1
# Óscar Plano     1  0
# Óscar Valentín  0  1
#
# [14039 rows x 2 columns]

# %%
player_salary = df[["Name","Wage"]]
player_salary.head()
# Out:
#                 Name      Wage
# 0           L. Messi  565000.0
# 1  Cristiano Ronaldo  405000.0
# 2          Neymar Jr  290000.0
# 4       K. De Bruyne  355000.0
# 5          E. Hazard  340000.0

# %%
player_salary = player_salary.sort_values(by=["Wage"],ascending=False)

# %%
player_salary.head()
# Out:
#                 Name      Wage
# 0           L. Messi  565000.0
# 7          L. Suárez  455000.0
# 6          L. Modrić  420000.0
# 1  Cristiano Ronaldo  405000.0
# 8       Sergio Ramos  380000.0

# %% [markdown]
# ### Hence Lionel Messi is the most paid player

# %%
plt.figure(figsize=(10,8))
plt.bar(list(player_salary["Name"])[:5],list(player_salary["Wage"])[:5],color='r')
plt.plot()
# Out:
# []

# %%
def lbstokgs(lbs):
    return float(lbs[:-3])*0.45359237

# %%
df["Weight"] = df["Weight"].apply(lambda x: lbstokgs(x))

# %%
df["Weight"].head()
# Out:
# 0    72.121187
# 1    83.007404
# 2    68.038855
# 4    69.853225
# 5    73.935556
# Name: Weight, dtype: float64

# %%
def foottocms(ft):
    return float(ft[0])*30.48

# %%
df["Height"] = df["Height"].apply(lambda y: foottocms(y))

# %%
df["Height"].head()
# Out:
# 0    152.40
# 1    182.88
# 2    152.40
# 4    152.40
# 5    152.40
# Name: Height, dtype: float64

# %%
df.sort_values(by=["Weight"],ascending=False).head()
# Out:
#            ID          Name  Age  \
# 9501   156321  A. Akinfenwa   36
# 15179  211415      M. Rhead   34
# 14111  244793      T. Chorý   23
# 1930   136113     W. Morgan   34
# 259    203263    H. Maguire   25
#
#                                                 Photo     Nationality  \
# 9501   https://cdn.sofifa.org/players/4/19/156321.png         England
# 15179  https://cdn.sofifa.org/players/4/19/211415.png         England
# 14111  https://cdn.sofifa.org/players/4/19/244793.png  Czech Republic
# 1930   https://cdn.sofifa.org/players/4/19/136113.png         Jamaica
# 259    https://cdn.sofifa.org/players/4/19/203263.png         England
#
#                                       Flag  Overall  Potential  \
# 9501   https://cdn.sofifa.org/flags/14.png       66         66
# 15179  https://cdn.sofifa.org/flags/14.png       60         60
# 14111  https://cdn.sofifa.org/flags/12.png       61         66
# 1930   https://cdn.sofifa.org/flags/82.png       75         75
# ...

# %% [markdown]
# ### Hence the player A. Akinfenwa is the most weighted player... Approx 110 kgs

# %%
df.sort_values(by=["Height"],ascending=False).head()
# Out:
#            ID            Name  Age  \
# 5788   208169        L. Gülen   24
# 14183  237910  Yeremi Valerón   21
# 7053   188779       L. DeVere   28
# 7050   190826    M. Hornschuh   27
# 14236  236394       S. Amuzie   22
#
#                                                 Photo  Nationality  \
# 5788   https://cdn.sofifa.org/players/4/19/208169.png  Switzerland
# 14183  https://cdn.sofifa.org/players/4/19/237910.png        Spain
# 7053   https://cdn.sofifa.org/players/4/19/188779.png    Australia
# 7050   https://cdn.sofifa.org/players/4/19/190826.png      Germany
# 14236  https://cdn.sofifa.org/players/4/19/236394.png      Nigeria
#
#                                        Flag  Overall  Potential  \
# 5788    https://cdn.sofifa.org/flags/47.png       69         73
# 14183   https://cdn.sofifa.org/flags/45.png       61         71
# 7053   https://cdn.sofifa.org/flags/195.png       68         68
# 7050    https://cdn.sofifa.org/flags/21.png       68         70
# ...

# %% [markdown]
# ### Hence L. Gülen is the tallest player

# %%
df["Height"].value_counts()
# Out:
# 152.40    8354
# 182.88    6389
# Name: Height, dtype: int64
